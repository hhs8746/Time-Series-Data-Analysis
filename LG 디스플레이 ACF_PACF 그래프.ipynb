# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#lg디스플레이 주가파일 불러오기 / 한국거래소 KRX정보 데이터 시스템에서 다운받았다.
dflg=pd.read_csv("lg_display.csv",encoding="CP949")
dflg.columns=['day','price']
#날짜를 인덱스화 한다.
dflg['day']=pd.to_datetime(dflg['day'])
dflg.index=dflg['day']
dflg.set_index('day',inplace=True)
#날짜를 오름차순으로 정렬한다.
dflg=dflg.sort_values('day',ascending=True)
dflg
# Out:
#             price
# day
# 2020-01-02  16350
# 2020-01-03  16250
# 2020-01-06  16000
# 2020-01-07  16350
# 2020-01-08  15650
# ...           ...
# 2022-12-20  13000
# 2022-12-21  12700
# 2022-12-22  13000
# 2022-12-23  12700
# 2022-12-26  12600
#
# [739 rows x 1 columns]

# %%
#lg디스플레이의 주가 그래프
dflg.plot()
# Out:
# <AxesSubplot:xlabel='day'>

# %%
#최근 10일을 제외한 나머지자료르 dflg2에 저장
#최근 10일을 dflg_p에 저장
dflg2=dflg.iloc[0:-10,:]
dflg_p=dflg.iloc[-10:,:]

# %%
#ACF그래프와 PACF그래프
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
fig = plot_acf(dflg2)
fig2 = plot_pacf(dflg2,method='ywm')

# %%
#정상성 검정
from statsmodels.tsa.stattools import adfuller
result = adfuller(dflg3['price'])
print('ADF Statistic:',result[0])
print('p-value:', result[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13736\2609868343.py in <module>
#       1 #정상성 검정
#       2 from statsmodels.tsa.stattools import adfuller
# ----> 3 result = adfuller(dflg3['price'])
#       4 print('ADF Statistic:',result[0])
#       5 print('p-value:', result[1])
#
# NameError: name 'dflg3' is not defined
